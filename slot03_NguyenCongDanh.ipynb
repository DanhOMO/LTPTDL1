# %%
import pandas as pd 
import seaborn as sns
df = pd.read_csv('dulieuxettuyendaihoc.csv',
                 header=0,delimiter=','
                 ,encoding='utf-8')
df = df[['GT','DT','KV','KT','M1',
         'M2','M3',
         'NGAYTHI','DINHHUONGNGHENGHIEP']]

# %%
print(f'{df["M1"].min()}\n{df["M1"].max()}\n')
print(f'{df["M1"].mean()}\n{df["M1"].median()}\n')
print(f'{df["KT"].mode()}\n')
print(f'{df["M1"].quantile(0.25)}\n')
# Out:
# 1.0
# 7.0
#
# 3.74
# 3.625
#
# 0    A
# Name: KT, dtype: object
#
# 2.5

# %%
print(df['M2'].max())
print(df['M2'].min())
print(df['M2'].mean())
print(df['M2'].median())
# Out:
# 8.0
# 1.5
# 4.255
# 4.125

# %%
df['M2'].max() - df['M2'].min()
# Out:
# 6.5

# %%
print(df['M1'].quantile(0.75))
print(df['M1'].quantile(0.25))
df['M1'].quantile(0.75) - df['M1'].quantile(0.25)
# Out:
# 4.75
# 2.5
# 2.25

# %%
import numpy as np
np.mean(np.abs(df['M1'] - np.mean(df['M1'])))
# Out:
# 1.1600000000000001

# %%
print(df[['M1','M2']].max())
df[['M1','M2']].max() - df[['M1','M2']].min()
# Out:
# M1    7.0
# M2    8.0
# dtype: float64
# M1    6.0
# M2    6.5
# dtype: float64

# %%
#TÍnh phương sai 
df['M1'].var()
# Out:
# 2.0289393939393943

# %%
df['M1'].std()
# Out:
# 1.424408436488423

# %%
print(df[['M1','M2']].mean())
print(df[['M1','M2']].std())
# Out:
# M1    3.740
# M2    4.255
# dtype: float64
# M1    1.424408
# M2    1.060053
# dtype: float64

# %%
df[['M1','M2']].std()/df[['M1','M2']].mean()
# Out:
# M1    0.380858
# M2    0.249131
# dtype: float64

# %%
df[['M1','M2','M3']].describe()
# Out:
#                M1          M2          M3
# count  100.000000  100.000000  100.000000
# mean     3.740000    4.255000    4.875000
# std      1.424408    1.060053    1.041136
# min      1.000000    1.500000    2.750000
# 25%      2.500000    3.500000    4.250000
# 50%      3.625000    4.125000    4.750000
# 75%      4.750000    4.750000    5.500000
# max      7.000000    8.000000    8.000000

# %%
cv = df[['M1','M2','M3']].std() / df[['M1','M2','M3']].mean()
cv
# Out:
# M1    0.380858
# M2    0.249131
# M3    0.213566
# dtype: float64

# %%
import matplotlib.pyplot as plt
df.groupby('GT')['M2'].std()/df.groupby('GT')['M2'].mean()
df['M1'].hist(color='green')
plt.show()

# %%
df['M1'].hist(bins=14)
plt.show()

# %%
sns.displot(df, x='M1', kind='kde')
plt.show()

# %%
sns.displot(data = df[['M1','M2','M3']], kind='kde')
plt.show()

# %%
df['M1'].skew()
# Out:
# 0.33322084231625376

# %%
df[['M1','M2','M3']].skew()
# Out:
# M1    0.333221
# M2    0.472551
# M3    0.607063
# dtype: float64

# %%
df[['M2']].kurtosis()
# Out:
# M2    1.372439
# dtype: float64

# %%
sns.displot(data = df[['M1','M2', 'M3']], kind='kde')
plt.show()

# %%
sns.boxplot(data=df['M1'], orient="h")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=df[['M1','M2','M3']], orient='h')
plt.show()

# %%
sns.boxplot(x='M1', y='GT',data=df, orient='h')
plt.show()

# %%
#từ hình bên dưới bạn có thế cho tôi biến giá trị ngoại lệ của hình là bao nhiêu không  ?
sns.boxplot(data=df[['M1','M2','M3']], orient='h')
plt.show()
# Mời bạn xem kỹ 
# giá trị ngoại lệ của hình là 0

# %%
from scipy import stats
stats.probplot(df['M1'],plot=sns.mpl.pyplot)
plt.show()

# %%
df[['M1','M2']].cov()
# Out:
#           M1        M2
# M1  2.028939  0.053081
# M2  0.053081  1.123712

# %%
sns.lmplot(data=df, x='M1', y='M2', fit_reg=True)
plt.show()

# %%
df[['M1','M2','M3']].corr()
# Out:
#           M1        M2        M3
# M1  1.000000  0.035154  0.018731
# M2  0.035154  1.000000 -0.091523
# M3  0.018731 -0.091523  1.000000

# %%
sns.heatmap(df[['M1','M2','M3']].corr(), vmax=1.0, square=False).xaxis.tick_top()

# %%
sns.lmplot(data=df, x='M1', y='M2',hue='GT', fit_reg=True)
plt.show()

# %%
sns.pairplot(df[['M1','M2','M3']],diag_kind='kde', kind='reg')
plt.show()
