# %%
import pandas as pd

# %%
#3
column_name = ['Id', 'Name', 'Age', 'Weight', 'm0006', 'm0612', 'm1218', 'f0006', 'f0612' , 'f1218' ]

df = pd.read_csv('patient_heart_rate.csv' )
df.head(10)
# Out:
#     Id            Name   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218
# 0  1.0    Mickéy Mousé  56.0       70kgs    72    69    71     -     -     -
# 1  2.0     Donald Duck  34.0   154.89lbs     -     -     -    85    84    76
# 2  3.0      Mini Mouse  16.0         NaN     -     -     -    65    69    72
# 3  4.0  Scrooge McDuck   NaN       78kgs    78    79    72     -     -     -
# 4  5.0    Pink Panther  54.0  198.658lbs     -     -     -    69   NaN    75
# 5  6.0     Huey McDuck  52.0      189lbs     -     -     -    68    75    72
# 6  7.0    Dewey McDuck  19.0       56kgs     -     -     -    71    78    75
# 7  8.0      Scööpy Doo  32.0       78kgs    78    76    75     -     -     -
# 8  NaN             NaN   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9  NaN             NaN   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
#4 
df[['Firstname', 'Lastname' ]] = df['Name'].str.split(expand=True)
df= df.drop('Name', axis=1)
df.head(10)
# Out:
#     Id   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218 Firstname
# 0  1.0  56.0       70kgs    72    69    71     -     -     -    Mickéy  \
# 1  2.0  34.0   154.89lbs     -     -     -    85    84    76    Donald
# 2  3.0  16.0         NaN     -     -     -    65    69    72      Mini
# 3  4.0   NaN       78kgs    78    79    72     -     -     -   Scrooge
# 4  5.0  54.0  198.658lbs     -     -     -    69   NaN    75      Pink
# 5  6.0  52.0      189lbs     -     -     -    68    75    72      Huey
# 6  7.0  19.0       56kgs     -     -     -    71    78    75     Dewey
# 7  8.0  32.0       78kgs    78    76    75     -     -     -    Scööpy
# 8  NaN   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 9  NaN   NaN         NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN
#
#   Lastname
# 0    Mousé
# 1     Duck
# 2    Mouse
# 3   McDuck
# 4  Panther
# 5   McDuck
# 6   McDuck
# 7      Doo
# 8      NaN
# 9      NaN

# %%
#5
weight = df['Weight']

for i in range(0, len(weight)):
    x = str(weight[i])
    if 'lbs' in x[-3:]:
        x = x[ : - 3:]
        float_x = float(x)
        y = int(float_x/2.2)
        y = str(y)
        weight[i]=y
    if 'kgs' in x[-3:]:
        x = x[ : - 3: ]
        float_x = float(x)
        weight[i]=x

# %%
df.rename(columns={'Weight':'Weight_kgs'},inplace=True)

# %%
df.head(5)
# Out:
#     Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname Lastname
# 0  1.0  56.0         70    72    69    71     -     -     -    Mickéy    Mousé
# 1  2.0  34.0         70     -     -     -    85    84    76    Donald     Duck
# 2  3.0  16.0        NaN     -     -     -    65    69    72      Mini    Mouse
# 3  4.0   NaN         78    78    79    72     -     -     -   Scrooge   McDuck
# 4  5.0  54.0         90     -     -     -    69   NaN    75      Pink  Panther

# %%
#6
df.dropna(how='all', axis=1, inplace=True)
df.head(9)
# Out:
#     Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname Lastname
# 0  1.0  56.0         70    72    69    71     -     -     -    Mickéy    Mousé
# 1  2.0  34.0         70     -     -     -    85    84    76    Donald     Duck
# 2  3.0  16.0        NaN     -     -     -    65    69    72      Mini    Mouse
# 3  4.0   NaN         78    78    79    72     -     -     -   Scrooge   McDuck
# 4  5.0  54.0         90     -     -     -    69   NaN    75      Pink  Panther
# 5  6.0  52.0         85     -     -     -    68    75    72      Huey   McDuck
# 6  7.0  19.0         56     -     -     -    71    78    75     Dewey   McDuck
# 7  8.0  32.0         78    78    76    75     -     -     -    Scööpy      Doo
# 8  NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN      NaN

# %%
#7
df = df.drop_duplicates(subset=['Firstname', 'Lastname', 'Age', 'Weight_kgs'])
df.head(5)
# Out:
#     Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname Lastname
# 0  1.0  56.0         70    72    69    71     -     -     -    Mickéy    Mousé
# 1  2.0  34.0         70     -     -     -    85    84    76    Donald     Duck
# 2  3.0  16.0        NaN     -     -     -    65    69    72      Mini    Mouse
# 3  4.0   NaN         78    78    79    72     -     -     -   Scrooge   McDuck
# 4  5.0  54.0         90     -     -     -    69   NaN    75      Pink  Panther

# %%
#``
df.Firstname.replace({r'[^\x00-\x7F]+':""},regex=True,inplace=True)
df.Lastname.replace({r'["\x00-\x7F]+':""},regex=True,inplace=True)
print (df )
# Out:
#       Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname
# 0    1.0  56.0         70    72    69    71     -     -     -     Micky  \
# 1    2.0  34.0         70     -     -     -    85    84    76    Donald
# 2    3.0  16.0        NaN     -     -     -    65    69    72      Mini
# 3    4.0   NaN         78    78    79    72     -     -     -   Scrooge
# 4    5.0  54.0         90     -     -     -    69   NaN    75      Pink
# 5    6.0  52.0         85     -     -     -    68    75    72      Huey
# 6    7.0  19.0         56     -     -     -    71    78    75     Dewey
# 7    8.0  32.0         78    78    76    75     -     -     -      Scpy
# 8    NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 11  10.0  12.0         45     -     -     -    92    95    87     Louie
# 12  11.0   NaN         60    78    75    72     -     -     -     Henry
# 13  12.0  34.0        NaN    65    67    55     -     -     -    Michel
# ...

# %%
#9
df['Age'].fillna(df['Age'].mode()[0], inplace=True)
df.head(9)
# Out:
#     Id   Age Weight_kgs m0006 m0612 m1218 f0006 f0612 f1218 Firstname Lastname
# 0  1.0  56.0         70    72    69    71     -     -     -     Micky        é
# 1  2.0  34.0         70     -     -     -    85    84    76    Donald
# 2  3.0  16.0        NaN     -     -     -    65    69    72      Mini
# 3  4.0  34.0         78    78    79    72     -     -     -   Scrooge
# 4  5.0  54.0         90     -     -     -    69   NaN    75      Pink
# 5  6.0  52.0         85     -     -     -    68    75    72      Huey
# 6  7.0  19.0         56     -     -     -    71    78    75     Dewey
# 7  8.0  32.0         78    78    76    75     -     -     -      Scpy
# 8  NaN  34.0        NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN      NaN

# %%
#10
df['Weight_kgs'].fillna(df['Weight_kgs'].median(), inplace=True)

# %%
#11
df = pd.melt(df, id_vars=['Id', 'Age', 'Weight_kgs', 'Firstname', 'Lastname'], 
                    value_name='PulseRate', var_name='gender_time').sort_values(['Id', 'Age', 'Weight_kgs', 'Firstname', 'Lastname'])
                    
df.head(8)
# Out:
#      Id   Age Weight_kgs Firstname Lastname gender_time PulseRate
# 0   1.0  56.0         70     Micky        é       m0006        72
# 15  1.0  56.0         70     Micky        é       m0612        69
# 30  1.0  56.0         70     Micky        é       m1218        71
# 45  1.0  56.0         70     Micky        é       f0006         -
# 60  1.0  56.0         70     Micky        é       f0612         -
# 75  1.0  56.0         70     Micky        é       f1218         -
# 1   2.0  34.0         70    Donald                m0006         -
# 16  2.0  34.0         70    Donald                m0612         -

# %%
df_temp = df['gender_time'].str.extract("(\D)(\d+)(\d{2})", expand=True)

# %%
df_temp.columns = ['Gender', 'Lower_hour', 'Upper_hour']
df_temp.head()
# Out:
#    Gender Lower_hour Upper_hour
# 0       m         00         06
# 15      m         06         12
# 30      m         12         18
# 45      f         00         06
# 60      f         06         12

# %%
df = pd.concat([df, df_temp], axis=1)

# %%
df.head()
# Out:
#      Id   Age Weight_kgs Firstname Lastname gender_time PulseRate Gender
# 0   1.0  56.0         70     Micky        é       m0006        72      m  \
# 15  1.0  56.0         70     Micky        é       m0612        69      m
# 30  1.0  56.0         70     Micky        é       m1218        71      m
# 45  1.0  56.0         70     Micky        é       f0006         -      f
# 60  1.0  56.0         70     Micky        é       f0612         -      f
#
#    Lower_hour Upper_hour
# 0          00         06
# 15         06         12
# 30         12         18
# 45         00         06
# 60         06         12

# %%
df = df.drop(['gender_time'], axis=1)
df.head()
# Out:
#      Id   Age Weight_kgs Firstname Lastname PulseRate Gender Lower_hour
# 0   1.0  56.0         70     Micky        é        72      m         00  \
# 15  1.0  56.0         70     Micky        é        69      m         06
# 30  1.0  56.0         70     Micky        é        71      m         12
# 45  1.0  56.0         70     Micky        é         -      f         00
# 60  1.0  56.0         70     Micky        é         -      f         06
#
#    Upper_hour
# 0          06
# 15         12
# 30         18
# 45         06
# 60         12

# %%
#12
import numpy as np

# %%
df = df.replace('-', np.nan).dropna(subset=['PulseRate'])
df.head()
# Out:
#      Id   Age Weight_kgs Firstname Lastname PulseRate Gender Lower_hour
# 0   1.0  56.0         70     Micky        é        72      m         00  \
# 15  1.0  56.0         70     Micky        é        69      m         06
# 30  1.0  56.0         70     Micky        é        71      m         12
# 46  2.0  34.0         70    Donald                 85      f         00
# 61  2.0  34.0         70    Donald                 84      f         06
#
#    Upper_hour
# 0          06
# 15         12
# 30         18
# 46         06
# 61         12

# %%
#13
df['Firstname'].isnull().sum()
# Out:
# 3

# %%
df['Lastname'].isnull().sum()
# Out:
# 3

# %%
#14
df = df.reset_index()

# %%
#15
df_unique = df.drop_duplicates(subset='Id')


df_unique.to_csv('benhNhan_unique.csv', index=False)

# %%
#1 bai Phan tich du lieu
import matplotlib.pyplot as plt

# %%
count_male = df['Gender'].value_counts()['m']
count_Female = df['Gender'].value_counts()['f']

# %%
labels = ['Nam','Nu']
size = [count_male , count_Female]

# %%
#1
plt.pie(size , labels=labels,autopct='%1.1f%%')
plt.show()

# %%
 #2
df['Fullname'] = df['Firstname'] + ' ' + df['Lastname']
 df.head()
# Out:
#    index   Id   Age Weight_kgs Firstname Lastname PulseRate Gender Lower_hour
# 0      0  1.0  56.0         70     Micky        é        72      m         00  \
# 1     15  1.0  56.0         70     Micky        é        69      m         06
# 2     30  1.0  56.0         70     Micky        é        71      m         12
# 3     46  2.0  34.0         70    Donald                 85      f         00
# 4     61  2.0  34.0         70    Donald                 84      f         06
#
#   Upper_hour Fullname
# 0         06  Micky é
# 1         12  Micky é
# 2         18  Micky é
# 3         06  Donald
# 4         12  Donald

# %%
#3
plt.bar(df['Id'], df['Age'])
plt.title('Age of patents')
plt.xlabel('ID')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
#4
plt.bar(df['Id'], df['PulseRate'])
plt.title('PulseRate of patents')
plt.xlabel('ID')
plt.ylabel('PulseRate')
# Out:
# Text(0, 0.5, 'PulseRate')

# %%
# 5. Vẽ biểu đồ cột so sánh nhịp tim trung bình theo từng nhóm giờ 00-06, 06-12,12-18 có 
# phân loại theo giới tính 
df['TimeGroup'] = df['Lower_hour'].astype(str) + df['Upper_hour']
plt.bar(df['TimeGroup'], df['PulseRate'])
plt.title('PulseRate of patents')
plt.xlabel('ID')
plt.ylabel('PulseRate')
# Out:
# Text(0, 0.5, 'PulseRate')

# %%
#6Vẽ biểu đồ phân tán thể hiện tương quan giữa trung bình độ tuổi và trung bình nhịp tim của bệnh nhân
plt.scatter(df['Age'], df['PulseRate'] )
plt.title('PulseRate and Age')
plt.xlabel('Age')
plt.ylabel('PulseRate')
# Out:
# Text(0, 0.5, 'PulseRate')

# %%
import seaborn as sns

# %%
# #  7 Vẽ biểu đồ đường thể hiện sự thay đổi của nhịp tim trung bình các bệnh nhân theo thứ tự 
# khung giờ 00-06, 06-12,12-18 theo từng nhóm giới tính.

df['TimeGroup'] = df['Lower_hour'].astype(str) + df['Upper_hour']
df = df.sort_values(['TimeGroup'])
sns.countplot(x='TimeGroup' , hue = 'Gender', data= df)
# Out:
# <Axes: xlabel='TimeGroup', ylabel='count'>
